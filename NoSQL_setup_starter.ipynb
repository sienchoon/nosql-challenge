# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
showdb = mongo.list_database_names()
print(showdb)
# Out:
# ['admin', 'config', 'local', 'met', 'schooldb', 'uk_food']

# %%
# assign the uk_food database to a variable name
ukfood = mongo['uk_food']

# %%
# review the collections in our new database
print(ukfood.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(ukfood.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6562d806c202e5fd704bc72f'),
#  'geocode': {'latitude': Decimal128('51.083812'),
#              'longitude': Decimal128('1.19562500000000')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = ukfood['establishments']
print(establishments)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food'), 'establishments')

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType": "Restaurant/Cafe/Canteen",
    "BusinessTypeID": "" ,
    "AddressLine1": "Penang Flavours",
    "AddressLine2": "146A Plumstead Rd",
    "AddressLine3": "London",
    "AddressLine4": "",
    "PostCode": "SE18 7DY",
    "Phone": "",
    "RatingValue":"",
    "RatingKey":"",
    "RatingDate":"",
    "LocalAuthorityCode":"",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance": 4623.972328074176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('6564405fb471770bd00a0e81'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
pprint(establishments.find_one(new_restaurant))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074176,
#  'LocalAuthorityCode': '',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingDate': '',
#  'RatingKey': '',
#  'RatingValue': '',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6564405fb471770bd00a0e81'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
business_type = {'BusinessType': 'Restaurant/Cafe/Canteen'}
business_id = {'BusinessTypeID': 1 ,'BusinessType' : 1 }

results = list(establishments.find(business_type, business_id))
pprint(results)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc72f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc73a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc73e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc742')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc743')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc752')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc758')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc75b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc75f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc760')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc763')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc764')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc774')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc77b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc77d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc783')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc787')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc788')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc78b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc78d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc790')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc792')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc793')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc794')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc795')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc79c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc79e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc79f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7a4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7d5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7f5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc7f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc800')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc801')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc802')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc808')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc80a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc80c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc80e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc814')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc815')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc817')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc818')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc819')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc81a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc81d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc822')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc824')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc825')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc827')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc834')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc835')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc838')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc839')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc83b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc841')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc842')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc845')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc847')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc849')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc84a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc850')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc853')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc855')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc85b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc865')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc87d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc881')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc883')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc88a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc88b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8ce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8d0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8f1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc8fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc904')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc905')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc906')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc907')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc908')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc909')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc90e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc90f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc91a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc91b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc91d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc91e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc920')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc922')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc92b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc92f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc931')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc936')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc938')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc93d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc93f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc940')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc943')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc94b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc951')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc957')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc95c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc95f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc961')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc965')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc968')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc96b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc973')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc977')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc97a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc97b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc97d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc97e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc982')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc988')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc98b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc98c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc98f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc996')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc999')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc99b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc99f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9a4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9b1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bc9f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca03')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca0d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca15')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca1a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca1f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca22')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca2a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca2f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca36')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca37')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca39')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca3c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca3d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca42')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca45')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca4a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca57')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca58')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca5d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca60')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca67')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca6a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca72')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca7a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca90')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bca9f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcaa0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcaa1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcaab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcac4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcac9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcaca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcacb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcacc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcadc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcadd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcade')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcae5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcae9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb12')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb13')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb15')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb19')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb1d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb1e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb24')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb26')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb2b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb2d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb34')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb35')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb37')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb51')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb53')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb55')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb59')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb5a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb65')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb68')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb69')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb71')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb77')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb88')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb8e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb94')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb95')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcb9f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcba6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcba7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcba9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbaf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbb5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbb9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbc2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbd3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbd4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbe1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbe4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbe9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbf2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcbf3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcc01')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcc04')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcc05')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcc07')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcc09')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcc0e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d806c202e5fd704bcc16')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc18')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc19')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc1a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc1b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc1d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc22')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc23')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc24')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc25')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc27')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc2c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc2f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc30')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc35')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc37')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc38')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc3c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc3f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc40')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc45')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc4a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc4d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc4f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc51')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc52')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc53')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc54')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc56')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc57')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc5a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc5c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc5e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc5f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc64')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc68')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc69')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc6a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc6e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc73')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc74')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc77')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc7e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc8a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc8e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc96')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcc97')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcca8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccaa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccaf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccb0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccbd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccc0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccc1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccc2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccc5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccd1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccd3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccd8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccd9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccda')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccdd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcce0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcce1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcce7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcce8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcce9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcced')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bccfd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd02')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd09')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd0e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd17')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd18')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd1d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd22')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd24')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd25')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd27')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd29')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd2a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd2d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd2e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd39')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd3f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd4f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd53')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd6c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd6e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd70')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd73')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd74')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd7a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd99')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcd9c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d807c202e5fd704bcda7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
# ...
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5da2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5da6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5da8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5da9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5db7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5db9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dbf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dc0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dc1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dc2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dc3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dc4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dc6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dc7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dcc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dcd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dcf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dd2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dd4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dd5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dd6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ddb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5de1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5de3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5de4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5de5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5de6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5de7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5de9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5def')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5df9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dfa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5dfd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e01')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e07')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e0a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e12')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e13')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e14')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e1d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e46')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e4a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e4f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e50')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e51')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e53')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e56')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e58')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e59')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e5a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e5c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e6d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e71')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e7d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e7f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e84')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e85')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e92')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e96')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e9b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e9d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5e9f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ea0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ea2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5eaa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ebb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ebf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ec9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5eca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ed0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ed5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5eda')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5edd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ee1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ee6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ee8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5eea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5eee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5ef7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5efa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5efc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5efd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5efe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f01')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f03')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f04')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f05')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f08')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f0a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f0b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f0c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f11')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f12')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f13')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f15')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f16')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f18')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f19')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f1a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f1b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f1e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f23')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f24')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f29')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f2b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f2d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f2e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f33')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f37')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f3a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f4a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f4f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f51')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f52')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f57')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f58')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f65')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f6f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f70')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f78')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f85')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f8a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f8f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f95')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f9a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5f9b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562d813c202e5fd704c5fa9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6562ec20b38ec9ed91c649dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   '_id': ObjectId('6564405fb471770bd00a0e81')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
ukfood.establishments.update_many(
    {'BusinessType': 'Restaurant/Cafe/Canteen'},
    {'$set':{'BusinessTypeID': 1}})
# Out:
# UpdateResult({'n': 9854, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName': 'Penang Flavours'}
results = list(establishments.find(query))
pprint(results)
# Out:
# [{'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'Distance': 4623.972328074176,
#   'LocalAuthorityCode': '',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RatingDate': '',
#   'RatingKey': '',
#   'RatingValue': '',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6562ec20b38ec9ed91c649dc'),
#   'geocode': {'latitude': Decimal128('51.49014200'),
#               'longitude': Decimal128('0.08384000')},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}},
#  {'AddressLine1': 'Penang Flavours',
#   'AddressLine2': '146A Plumstead Rd',
#   'AddressLine3': 'London',
#   'AddressLine4': '',
#   'BusinessName': 'Penang Flavours',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'Distance': 4623.972328074176,
#   'LocalAuthorityCode': '',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': True,
#   'Phone': '',
#   'PostCode': 'SE18 7DY',
#   'RatingDate': '',
#   'RatingKey': '',
#   'RatingValue': '',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6564405fb471770bd00a0e81'),
#   'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#   'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}]

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_query = {'$match': {'LocalAuthorityName': 'Dover'}}
pipeline = [dover_query]
results = list(establishments.aggregate(pipeline))
print("Number of documents: ",len(results),"\n")
# Out:
# Number of documents:  0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})
# Out:
# DeleteResult({'n': 0, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
print("Number of documents: ",establishments.count_documents({'LocalAuthorityName': 'Dover'}),"\n")
# Out:
# Number of documents:  0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6562d806c202e5fd704bc72f'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set':{ "geocode.longitude" : {'$toDouble': "$geocode.longitude"}}} ])
# Out:
# UpdateResult({'n': 38786, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ {'$set':{ "geocode.latitude" : {'$toDouble': "$geocode.latitude"}}} ])
# Out:
# UpdateResult({'n': 38786, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, 
                           [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 0, 'nModified': 0, 'ok': 1.0, 'updatedExisting': False}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, 
                           [ {"$set":
                               { "RatingValue" : {"$toInt": "$RatingValue"}}
                               } 
                            ])
# Out:
# UpdateResult({'n': 38785, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
print(type(establishments.find_one()['geocode']['longitude']))
print(type(establishments.find_one()['geocode']['latitude']))
print(type(establishments.find_one()['RatingValue']))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'int'>
